# %% [markdown]
# 1

# %%
import time
from PIL import Image # Pillow
import array

# %%
x1, x2, y1, y2 = -1.8, 1.8, -1.8, 1.8
c_real, c_imag = -0.62772, -.42193
def calculate_z_serial_purepython(maxiter, zs, cs):
    """Calculate list"""
    output = [0] * len(zs)
    for i in range(len(zs)):
        n = 0
        z = zs[i]
        c = cs[i]
        while abs(z) < 2 and n < maxiter:
            z = z * z + c
            n += 1
        output[i] = n
    return output
def calc_pure_python(desired_width, max_iterations):
    """Create a list of zs and cs, build Julia set and display using PIL"""
    x_step = (float(x2 - x1) / float(desired_width))
    y_step = (float(y1 - y2) / float(desired_width))
    x = []
    y = []
    ycoord = y2
    while ycoord > y1:
        y.append(ycoord)
        ycoord += y_step
    xcoord = x1
    while xcoord < x2:
        x.append(xcoord)
        xcoord += x_step
    # build a list and the initial condition.
    zs = []
    cs = []
    for ycoord in y:
        for xcoord in x:
            zs.append(complex(xcoord, ycoord))
            cs.append(complex(c_real, c_imag))

    print("Length of x:", len(x))
    print("Total elements:", len(zs))
    start_time = time.time()
    output = calculate_z_serial_purepython(max_iterations, zs, cs)
    end_time = time.time()
    secs = end_time - start_time
    print(calculate_z_serial_purepython.__name__ + " took", secs, "seconds")

    # 1000^2 grid with 300 iterations
    assert sum(output) == 33219980

if __name__ == "__main__":
    # Calculate the Julia set 
    # set draw_output
    calc_pure_python(desired_width=1000, max_iterations=300)
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.4129815101623535 seconds

# %%
# area of complex space to be rendered
x1, x2, y1, y2 = -1.8, 1.8, -1.8, 1.8
c_real, c_imag = -0.62772, -.42193
def show_greyscale(output_raw, width, height, max_iterations):
    """Convert list to array, show using PIL"""
    # convert scale to [0...255]
    max_iterations = float(max(output_raw))
    print(max_iterations)
    scale_factor = float(max_iterations)
    scaled = [int(o / scale_factor * 255) for o in output_raw]
    output = array.array('B', scaled)  # array of unsigned ints
    # display
    im = Image.new("L", (width, width))
    # Greyscale
    im.frombytes(output.tobytes(), "raw", "L", 0, -1)
    im.show(title="Greyscale Julia Set")

def show_false_greyscale(output_raw, width, height, max_iterations):
    """Convert list to array, show using PIL"""
    # convert scale to [0...255]
    assert width * height == len(output_raw)
    # normalise to 0-255
    max_value = float(max(output_raw))
    output_raw_limited = [int(float(o) / max_value * 255) for o in output_raw]
    # fancy RGB
    output_rgb = (
        (o + (256 * o) + (256 ** 2) * o) * 16 for o in output_raw_limited)  # fancier
    # convert to bytes
    output_rgb = array.array('I', output_rgb)
    # display
    im = Image.new("RGB", (width, height))
    # False colour
    im.frombytes(output_rgb.tobytes(), "raw", "RGBX", 0, -1)
    im.show(title="False Greyscale Julia Set")

def calculate_z_serial_purepython(maxiter, zs, cs):
    """Calculate list"""
    output = [0] * len(zs)
    for i in range(len(zs)):
        n = 0
        z = zs[i]
        c = cs[i]
        while abs(z) < 2 and n < maxiter:
            z = z * z + c
            n += 1
        output[i] = n
    return output

def calc_pure_python( desired_width, max_iterations):
    """Create a list of zs and cs, build Julia set and display using PIL"""
    x_step = (float(x2 - x1) / float(desired_width))
    y_step = (float(y1 - y2) / float(desired_width))
    x = []
    y = []
    ycoord = y2
    while ycoord > y1:
        y.append(ycoord)
        ycoord += y_step
    xcoord = x1
    while xcoord < x2:
        x.append(xcoord)
        xcoord += x_step
    width = len(x)
    height = len(y)
    # build a list of co-ordinates and the initial condition 
    zs = []
    cs = []
    for ycoord in y:
        for xcoord in x:
            zs.append(complex(xcoord, ycoord))
            cs.append(complex(c_real, c_imag))

    print("Length of x:", len(x))
    print("Total elements:", len(zs))
    start_time = time.time()
    output = calculate_z_serial_purepython(max_iterations, zs, cs)
    end_time = time.time()
    secs = end_time - start_time
    print(calculate_z_serial_purepython.__name__ + " took", secs, "seconds")

    # 1000^2 grid with 300 iterations
    assert sum(output) == 33219980
    

    
if __name__ == "__main__":
    # Calculate the Julia set
    calc_pure_python(desired_width=1000, max_iterations=300)
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.489577770233154 seconds

# %% [markdown]
# 2

# %%
import time
from functools import wraps
def timefn(function):
    @wraps(function)
    def measure_time(*args, **kwargs):
        t1 = time.time()
        result = function(*args, **kwargs)
        t2 = time.time()
        total_time = t2 - t1
        print(f"{function.__name__} took {total_time} seconds")
        return result
    return measure_time
    
@timefn
def calculate_z_serial_purepython(maxiter, zs, cs):
    """Executes Julia set calculation"""
    output = [0] * len(zs)
    for i in range(len(zs)):
        n = 0
        z = zs[i]
        c = cs[i]
        while abs(z) < 2 and n < maxiter:
            z = z * z + c
            n += 1
        output[i] = n
    return output
if __name__ == "__main__":
     # Compute Julia set with Python only; settings optimized for laptops
    calc_pure_python(desired_width=1000, max_iterations=300)
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.406877756118774 seconds
# calculate_z_serial_purepython took 5.406999349594116 seconds

# %% [markdown]
# 3

# %%
# %timeit -r 5 -n 10 calc_pure_python(desired_width=1000, max_iterations=300)
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.437307357788086 seconds
# calculate_z_serial_purepython took 5.4374377727508545 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.465422630310059 seconds
# calculate_z_serial_purepython took 5.46554708480835 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.480901718139648 seconds
# calculate_z_serial_purepython took 5.481020212173462 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.450598478317261 seconds
# calculate_z_serial_purepython took 5.450705289840698 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.491135358810425 seconds
# calculate_z_serial_purepython took 5.4912543296813965 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.456660747528076 seconds
# calculate_z_serial_purepython took 5.456775426864624 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.401425838470459 seconds
# calculate_z_serial_purepython took 5.401543378829956 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.436996698379517 seconds
# calculate_z_serial_purepython took 5.437116861343384 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.44504189491272 seconds
# calculate_z_serial_purepython took 5.44516396522522 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.436832427978516 seconds
# calculate_z_serial_purepython took 5.436953783035278 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.396000146865845 seconds
# calculate_z_serial_purepython took 5.396120071411133 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.413599729537964 seconds
# calculate_z_serial_purepython took 5.413708448410034 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.3918938636779785 seconds
# calculate_z_serial_purepython took 5.392007350921631 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.3621838092803955 seconds
# calculate_z_serial_purepython took 5.362324476242065 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.422252178192139 seconds
# calculate_z_serial_purepython took 5.4223573207855225 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.42913031578064 seconds
# calculate_z_serial_purepython took 5.4292521476745605 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.409355163574219 seconds
# calculate_z_serial_purepython took 5.409467697143555 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.4166412353515625 seconds
# calculate_z_serial_purepython took 5.416749715805054 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.4251039028167725 seconds
# calculate_z_serial_purepython took 5.425244331359863 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.404693841934204 seconds
# calculate_z_serial_purepython took 5.404805898666382 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.384639024734497 seconds
# calculate_z_serial_purepython took 5.384753227233887 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.398867130279541 seconds
# calculate_z_serial_purepython took 5.398983478546143 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.408695936203003 seconds
# calculate_z_serial_purepython took 5.40882134437561 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.403512716293335 seconds
# calculate_z_serial_purepython took 5.403650283813477 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.43416166305542 seconds
# calculate_z_serial_purepython took 5.434277057647705 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.393792629241943 seconds
# calculate_z_serial_purepython took 5.393930435180664 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.419013261795044 seconds
# calculate_z_serial_purepython took 5.419124364852905 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.426672458648682 seconds
# calculate_z_serial_purepython took 5.4267966747283936 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.402525424957275 seconds
# calculate_z_serial_purepython took 5.402650356292725 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.4006288051605225 seconds
# calculate_z_serial_purepython took 5.400741815567017 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.3726372718811035 seconds
# calculate_z_serial_purepython took 5.372750997543335 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.36585807800293 seconds
# calculate_z_serial_purepython took 5.365967750549316 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.337296962738037 seconds
# calculate_z_serial_purepython took 5.337426662445068 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.359898328781128 seconds
# calculate_z_serial_purepython took 5.3600263595581055 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.446775674819946 seconds
# calculate_z_serial_purepython took 5.446910619735718 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.418877601623535 seconds
# calculate_z_serial_purepython took 5.419024467468262 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.412867307662964 seconds
# calculate_z_serial_purepython took 5.412970066070557 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.412562847137451 seconds
# calculate_z_serial_purepython took 5.412674427032471 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.437423229217529 seconds
# calculate_z_serial_purepython took 5.437533378601074 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.420291900634766 seconds
# calculate_z_serial_purepython took 5.4203972816467285 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.418970823287964 seconds
# calculate_z_serial_purepython took 5.419098854064941 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.358263254165649 seconds
# calculate_z_serial_purepython took 5.358397960662842 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.369343519210815 seconds
# calculate_z_serial_purepython took 5.369465351104736 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.435720682144165 seconds
# calculate_z_serial_purepython took 5.435849189758301 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.424646377563477 seconds
# calculate_z_serial_purepython took 5.424773693084717 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.44425892829895 seconds
# calculate_z_serial_purepython took 5.444389820098877 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.427668333053589 seconds
# calculate_z_serial_purepython took 5.427779197692871 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.384648561477661 seconds
# calculate_z_serial_purepython took 5.384783983230591 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.391970872879028 seconds
# calculate_z_serial_purepython took 5.392092704772949 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.397843837738037 seconds
# calculate_z_serial_purepython took 5.39795708656311 seconds
# 5.75 s ± 20.5 ms per loop (mean ± std. dev. of 5 runs, 10 loops each)

# %% [markdown]
# 4

# %%
import cProfile
import pstats
profiler = cProfile.Profile()
profiler.enable()
calc_pure_python( desired_width=1000, max_iterations=300)
profiler.disable()
stats = pstats.Stats(profiler).sort_stats('cumulative')
stats.print_stats()
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 96.0306031703949 seconds
# calculate_z_serial_purepython took 96.03080344200134 seconds
#          36222233 function calls in 101.853 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000  101.886   50.943 /home/carlo/Documentos/Performance_CM_07_Jan-Apr/CA3._High_Performance_Python/ca3/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3541(run_code)
#         2    0.000    0.000  101.886   50.943 {built-in method builtins.exec}
#         1    3.142    3.142  101.852  101.852 /tmp/ipykernel_30323/67956430.py:49(calc_pure_python)
#         1    0.000    0.000   96.031   96.031 /tmp/ipykernel_30323/3969873473.py:4(measure_time)
#         1   50.255   50.255   96.031   96.031 /tmp/ipykernel_30323/3969873473.py:14(calculate_z_serial_purepython)
#  34219980   45.775    0.000   45.775    0.000 {built-in method builtins.abs}
#   2002000    2.675    0.000    2.675    0.000 {method 'append' of 'list' objects}
#         1    0.004    0.004    0.004    0.004 {built-in method builtins.sum}
#         4    0.000    0.000    0.001    0.000 {built-in method builtins.print}
#        16    0.000    0.000    0.001    0.000 /home/carlo/Documentos/Performance_CM_07_Jan-Apr/CA3._High_Performance_Python/ca3/lib/python3.10/site-packages/ipykernel/iostream.py:655(write)
#        16    0.000    0.000    0.000    0.000 /home/carlo/Documentos/Performance_CM_07_Jan-Apr/CA3._High_Performance_Python/ca3/lib/python3.10/site-packages/ipykernel/iostream.py:577(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 /home/carlo/Documentos/Performance_CM_07_Jan-Apr/CA3._High_Performance_Python/ca3/lib/python3.10/site-packages/ipykernel/iostream.py:259(schedule)
#        16    0.000    0.000    0.000    0.000 /home/carlo/Documentos/Performance_CM_07_Jan-Apr/CA3._High_Performance_Python/ca3/lib/python3.10/site-packages/ipykernel/iostream.py:550(_is_master_process)
#        16    0.000    0.000    0.000    0.000 /home/carlo/Documentos/Performance_CM_07_Jan-Apr/CA3._High_Performance_Python/ca3/lib/python3.10/site-packages/ipykernel/iostream.py:505(parent_header)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/codeop.py:117(__call__)
#         2    0.000    0.000    0.000    0.000 /home/carlo/Documentos/Performance_CM_07_Jan-Apr/CA3._High_Performance_Python/ca3/lib/python3.10/site-packages/zmq/sugar/socket.py:621(send)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#        22    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/threading.py:1169(is_alive)
#        16    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         2    0.000    0.000    0.000    0.000 /home/carlo/Documentos/Performance_CM_07_Jan-Apr/CA3._High_Performance_Python/ca3/lib/python3.10/site-packages/traitlets/traitlets.py:676(__get__)
#        16    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        16    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#        16    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#        16    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        16    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/contextlib.py:279(helper)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/contextlib.py:130(__enter__)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/contextlib.py:139(__exit__)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/threading.py:1102(_wait_for_tstate_lock)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/contextlib.py:102(__init__)
#         2    0.000    0.000    0.000    0.000 /home/carlo/Documentos/Performance_CM_07_Jan-Apr/CA3._High_Performance_Python/ca3/lib/python3.10/site-packages/traitlets/traitlets.py:629(get)
#         4    0.000    0.000    0.000    0.000 {built-in method time.time}
#         4    0.000    0.000    0.000    0.000 /home/carlo/Documentos/Performance_CM_07_Jan-Apr/CA3._High_Performance_Python/ca3/lib/python3.10/site-packages/IPython/core/compilerop.py:180(extra_flags)
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_30323/324011351.py:1(<module>)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         2    0.000    0.000    0.000    0.000 /home/carlo/Documentos/Performance_CM_07_Jan-Apr/CA3._High_Performance_Python/ca3/lib/python3.10/site-packages/ipykernel/iostream.py:138(_event_pipe)
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 /usr/lib/python3.10/typing.py:1737(cast)
#         2    0.000    0.000    0.000    0.000 /home/carlo/Documentos/Performance_CM_07_Jan-Apr/CA3._High_Performance_Python/ca3/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3493(compare)
#         2    0.000    0.000    0.000    0.000 /home/carlo/Documentos/Performance_CM_07_Jan-Apr/CA3._High_Performance_Python/ca3/lib/python3.10/site-packages/IPython/core/interactiveshell.py:1277(user_global_ns)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/threading.py:553(is_set)
#         2    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 /home/carlo/Documentos/Performance_CM_07_Jan-Apr/CA3._High_Performance_Python/ca3/lib/python3.10/site-packages/dateutil/tz/tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# 5

# %%
# %load_ext snakeviz


cProfile.run('calc_pure_python(desired_width=1000, max_iterations=300)', 'profiling')

# !snakeviz "profiling"
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 96.20192503929138 seconds
# calculate_z_serial_purepython took 96.20214200019836 seconds
# snakeviz web server started on 127.0.0.1:8080; enter Ctrl-C to exit
# http://127.0.0.1:8080/snakeviz/%2Fhome%2Fcarlo%2FDocumentos%2FPerformance_CM_07_Jan-Apr%2FCA3._High_Performance_Python%2F1%2Fprofiling
# ^C
#
# Bye!

# %% [markdown]
# 6

# %%
# %load_ext line_profiler
# %lprun -f calculate_z_serial_purepython calc_pure_python(desired_width=1000, max_iterations=300)
# Out:
# /home/carlo/Documentos/Performance_CM_07_Jan-Apr/CA3._High_Performance_Python/ca3/lib/python3.10/site-packages/line_profiler/ipython_extension.py:97: UserWarning: Adding a function with a __wrapped__ attribute. You may want to profile the wrapped function by adding calculate_z_serial_purepython.__wrapped__ instead.
#   profile = LineProfiler(*funcs)
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 14.65920877456665 seconds
# calculate_z_serial_purepython took 14.659426927566528 seconds
# Timer unit: 1e-09 s
#
# Total time: 14.6594 s
# File: /tmp/ipykernel_30323/3969873473.py
# Function: measure_time at line 4
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      4                                               @wraps(function)
#      5                                               def measure_time(*args, **kwargs):
#      6         1       5727.0   5727.0      0.0          t1 = time.time()
#      7         1        1e+10    1e+10    100.0          result = function(*args, **kwargs)
#      8         1       7613.0   7613.0      0.0          t2 = time.time()
#      9         1       2305.0   2305.0      0.0          total_time = t2 - t1
#     10         1     162802.0 162802.0      0.0          print(f"{function.__name__} took {total_time} seconds")
#     11         1       1956.0   1956.0      0.0          return result

# %% [markdown]
# 7

# %%
# %reload_ext memory_profiler 
# %memit calc_pure_python(desired_width=1000, max_iterations=300)
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 5.490455150604248 seconds
# calculate_z_serial_purepython took 5.49060583114624 seconds
# peak memory: 167.39 MiB, increment: 85.88 MiB
